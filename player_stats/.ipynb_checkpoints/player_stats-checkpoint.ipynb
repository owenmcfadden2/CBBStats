# %%
import pandas as pd
import numpy as np

# %%
jordan_pope_data = pd.read_csv('data/jordan_pope.txt')
jordan_pope_data
# Out:
#         Rk   Gcar   Gtm        Date          Team Unnamed: 5             Opp  \
# 0      NaN    NaN   NaN         NaN           NaN        NaN             NaN
# 1      1.0    1.0   1.0  2022-11-08  Oregon State        NaN           Tulsa
# 2      2.0    2.0   2.0  2022-11-11  Oregon State        NaN     Florida A&M
# 3      3.0    3.0   3.0  2022-11-15  Oregon State        NaN        Bushnell
# 4      4.0    4.0   4.0  2022-11-19  Oregon State        NaN  Portland State
# ..     ...    ...   ...         ...           ...        ...             ...
# 108  108.0  108.0   9.0  2025-12-03         Texas        NaN        Virginia
# 109  109.0  109.0  10.0  2025-12-08         Texas        NaN        Southern
# 110  110.0  110.0  11.0  2025-12-12         Texas          @     Connecticut
# 111  111.0  111.0  12.0  2025-12-16         Texas        NaN        Le Moyne
# 112    NaN    NaN   NaN         NaN           NaN        NaN             NaN
#
# ...
